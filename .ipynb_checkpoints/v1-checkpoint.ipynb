# %%
# %pip install requests
# %pip install jieba
# %pip install matplotlib
# %pip install graphviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /usr/lib/python3.10/site-packages (2.28.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3.10/site-packages (from requests) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.10/site-packages (from requests) (3.4)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jieba in /home/matto/.local/lib/python3.10/site-packages (0.42.1)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/matto/.local/lib/python3.10/site-packages (3.7.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/matto/.local/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/matto/.local/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/matto/.local/lib/python3.10/site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/matto/.local/lib/python3.10/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: numpy>=1.20 in /usr/lib/python3.10/site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.10/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: graphviz in /home/matto/.local/lib/python3.10/site-packages (0.20.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
# get word frequency list

def parse_word(e):
    l = e.split(" ")
    if len(l) < 3:
        print("malformed entry:", l)
        return {"rank": 0, "freq": "0", "word": l[0]}
    return {
        "rank": int(l[0]),
        "freq": float(l[1]),
        "word": l[2],
    }

r = requests.get("http://corpus.leeds.ac.uk/frqc/internet-zh.num")
word_freq = list(map(parse_word, r.text.split("\n")[4:-1]))
print(len(word_freq), "words retrieved")
# Out:
# 50000 words retrieved

# %%
# %%bash
# # download example sentences with translations
# wget "http://www.manythings.org/anki/cmn-eng.zip" -O cmn-eng.zip 2>&1 | grep ERROR
# unzip -oq cmn-eng.zip -d cmn-eng && echo "done"
# Out:
# done

# %%
# parse example sentences file

def parse_example(e):
    l = e[:-1].split("\t")
    return {
        "cmn": l[1],
        "eng": l[0],
        "attr": l[2],
        "dup": False
    }

with open("cmn-eng/cmn.txt") as f:
    lines = f.readlines()
    
sentences = list(map(parse_example, lines))
print(len(sentences), "sentences retrieved")

translations = {}
for i in range(len(sentences)):
    if not sentences[i]["cmn"] in translations:
        translations[sentences[i]["cmn"]] = []
    else:
        sentences[i]["dup"] = True
    translations[sentences[i]["cmn"]].append(i)
# Out:
# 29476 sentences retrieved

# %%
def get_word_rank(word):
    if word in word_map:
        return word_map[word]["rank"]
    else:
        rank = 0
        for c in word:
            if c in word_map:
                rank = max(rank, word_map[c]["rank"])
            else:
                return len(word_freq)
        return rank

# %%
# cut sentences into words, and more

import jieba

word_map = {}
for i in range(len(word_freq)):
    word_map[word_freq[i]["word"]] = {
        "rank": word_freq[i]["rank"],
        "freq": word_freq[i]["freq"],
        "sentences": [] # indices of sentences which contain this word
    }

always_use_char_freq = True # if this is false, then character frequency is used only as a fallback when none of the words are on the frequency list
    
# for i in range(len(sentences)):
#     sentences[i]["words"] = jieba.lcut(sentences[i]["cmn"])
#     sentences[i]["wc"] = len(sentences[i]["words"]) # word count
#     sentences[i]["maxrank"] = -1 # rank of the least common word
#     ranks = []
#     for word in sentences[i]["words"]:
#         if word in word_map:
#             word_map[word]["sentences"].append(i)
#             sentences[i]["maxrank"] = max(sentences[i]["maxrank"], word_map[word]["rank"])
#             ranks.append(word_map[word]["rank"])
#     if always_use_char_freq or sentences[i]["maxrank"] == -1: # fallback: check for character frequency
#         if sentences[i]["maxrank"] == -1:
#             sentences[i]["maxrank"] = len(word_freq)
#         for word in list(sentences[i]["cmn"]):
#             if word in word_map:
#                 word_map[word]["sentences"].append(i)
#                 #sentences[i]["maxrank"] = max(sentences[i]["maxrank"], word_map[word]["rank"])
#                 ranks.append(word_map[word]["rank"])
#     if len(ranks) > 0:
#         sentences[i]["avgrank"] = sum(ranks) / len(ranks)
#     if sentences[i]["maxrank"] == -1:
#         print("Couldn't determine maxrank for sentence", i, sentences[i]["words"], sentences[i]["eng"])
#         sentences[i]["maxrank"] = len(word_freq)
#         sentences[i]["avgrank"] = sentences[i]["maxrank"]

for i in range(len(sentences)):
    sentences[i]["words"] = jieba.lcut(sentences[i]["cmn"])
    sentences[i]["wc"] = len(sentences[i]["words"]) # word count
    ranks = []
    for word in sentences[i]["words"]:
        ranks.append(get_word_rank(word))
        if word in word_map:
            word_map[word]["sentences"].append(i)
    assert len(ranks) > 0
    sentences[i]["maxrank"] = max(ranks)
    sentences[i]["avgrank"] = sum(ranks) / len(ranks)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.536 seconds.
# Prefix dict has been built successfully.

# %%
import matplotlib.pyplot as plt

xs = []
ys = []

for i in range(len(word_freq)):
    for sid in word_map[word_freq[i]["word"]]["sentences"]:
        xs.append(word_freq[i]["rank"])
        ys.append(sentences[sid]["avgrank"])
    
fig, ax = plt.subplots()
ax.scatter(xs, ys, s=0.5)
plt.show()

# %%
# a test for sentence selection

sent = []
wid = 1000 #236
for sid in word_map[word_freq[wid]["word"]]["sentences"]:
    sent.append(sid)
    
sent.sort(key=(lambda sid : sentences[sid]["maxrank"]*len(word_freq) - sentences[sid]["avgrank"]*sentences[sid]["wc"]))
    
print("("+str(word_freq[wid]["rank"]), word_freq[wid]["word"]+")\nmax\tavg\twc\tavg*wc")    
for sid in sent:
    if not sentences[sid]["dup"]:
        print(sentences[sid]["maxrank"], "%.2f" % sentences[sid]["avgrank"], sentences[sid]["wc"], int(sentences[sid]["avgrank"])*sentences[sid]["wc"], sentences[sid]["cmn"], "\n\t\t\t\t\t\t\t"+sentences[sid]["eng"], sep="\t")
# Out:
# (1001 支)
# max	avg	wc	avg*wc
# 5381	1137.14	7	7959	能借我支铅笔吗？
# 							Would you lend me a pencil?
# 5381	1140.17	6	6840	你有多少支铅笔？
# 							How many pens do you have?
# 50000	13621.25	8	108968	我比你多10支钢笔。
# 							I have ten pens more than you do.
# 50000	12217.33	6	73302	你有多少支球拍?
# 							How many rackets do you have?
# 50000	9401.17	6	56406	给我支香烟吧。
# 							Give me a cigarette.

# %%
# first method for card creation

cards = []
count = 0
for word in word_freq:
    sent = []
    for sid in word_map[word["word"]]["sentences"]:
        sent.append(sid)

    sent.sort(key=(lambda sid : sentences[sid]["maxrank"]*len(word_freq) - sentences[sid]["avgrank"]*sentences[sid]["wc"]))
    
    if len(sent) == 0:
        pass
        # print("no example sentences for word", word)
    else:
        sid = sent[0]
        if sentences[sid]["maxrank"] <= word["rank"] + 10 or (sentences[sid]["maxrank"] <= 120 and word["rank"] < 100) or (sentences[sid]["avgrank"] < word["rank"]/2):
            count += 1
            print("%3d|" % word["rank"], "%-3s\t" % word["word"], "+%d" % (sentences[sid]["maxrank"]-word["rank"]), "\t",
                  sentences[sid]["maxrank"], "\t%.2f\t" % sentences[sid]["avgrank"],
                  sentences[sid]["cmn"], sentences[sid]["eng"])
print(count, "/", len(word_freq), "=", 100*count/len(word_freq), "%")
# Out:
#   1| ，  	 +100 	 101 	33.86	 那不对，对吧？ That isn't true, is it?
#   2| 的  	 +58 	 60 	19.50	 你说的是什么？ What are you talking about?
#   3| 了  	 +54 	 57 	18.60	 你想我了？ Do you miss me?
#   4| 我  	 +53 	 57 	18.60	 你想我了？ Do you miss me?
#   6| 在  	 +54 	 60 	26.00	 你在看什么？ What're you reading?
#   7| 是  	 +53 	 60 	32.25	 那是什么？ What's that?
#   9| 他  	 +51 	 60 	21.80	 他说了什么？ What did he say?
#  11| 你  	 +46 	 57 	18.60	 你想我了？ Do you miss me?
#  13| 不  	 +88 	 101 	33.86	 那不对，对吧？ That isn't true, is it?
#  14| 有  	 +96 	 110 	40.83	 有什么不对吗？ Is something wrong?
#  16| 这  	 +94 	 110 	35.88	 这是对的，不是吗？ That's right, isn't it?
#  18| ？  	 +39 	 57 	18.60	 你想我了？ Do you miss me?
#  19| 说  	 +41 	 60 	28.43	 你想对我说什么？ What do you want to tell me?
#  21| 她  	 +39 	 60 	24.20	 她说了什么？ What did she say?
#  23| 都  	 +90 	 113 	50.40	 什么问题都没有！ No problem at all!
#  24| ！  	 +6 	 30 	27.00	 对！ That's right.
#  25| 我们 	 +59 	 84 	37.67	 你要我们做什么？ What did you want us to do?
#  28| 要  	 +56 	 84 	37.67	 你要我们做什么？ What did you want us to do?
#  30| 对  	 +0 	 30 	27.00	 对！ That's right.
#  32| 没有 	 +53 	 85 	34.50	 知道了没有？ Got it?
#  34| 到  	 +76 	 110 	57.62	 你知道他们什么时候到吗？ Do you know when they will arrive?
#  35| 看  	 +25 	 60 	26.00	 你在看什么？ What're you reading?
#  36| 去  	 +74 	 110 	49.71	 我现在能去了吗？ May I go now?
#  37| 来  	 +0 	 37 	32.00	 来看看！ Come and take a look.
#  43| 还  	 +66 	 109 	54.67	 还在等什么呢！ What're you waiting for?
#  44| 那  	 +16 	 60 	32.25	 那是什么？ What's that?
#  45| 会  	 +20 	 65 	35.29	 那你会给我什么？ So, what'll you give me?
#  48| 他们 	 +62 	 110 	57.62	 你知道他们什么时候到吗？ Do you know when they will arrive?
#  57| 想  	 +0 	 57 	18.60	 你想我了？ Do you miss me?
#  60| 什么 	 +0 	 60 	28.43	 你想对我说什么？ What do you want to tell me?
#  65| 给  	 +0 	 65 	35.29	 那你会给我什么？ So, what'll you give me?
#  66| 让  	 +44 	 110 	46.29	 你能让我看看吗？ Would you like me to take a look?
#  68| 可以 	 +42 	 110 	53.00	 可以给我吗？ Can I have it?
#  80| 能  	 +30 	 110 	59.86	 我现在能走了吗？ May I leave now?
#  84| 做  	 +0 	 84 	37.67	 你要我们做什么？ What did you want us to do?
#  85| 知道 	 +0 	 85 	34.50	 知道了没有？ Got it?
#  86| 等  	 +0 	 86 	59.67	 等一下！ Wait!
#  91| 最  	 +68 	 159 	44.00	 最不一样的的是什么？ What's the biggest difference?
#  95| 时候 	 +12 	 107 	58.20	 你什么时候走？ What time are you leaving?
#  96| 没  	 +17 	 113 	77.67	 没问题！ No problem!
#  97| 现在 	 +0 	 97 	48.60	 你现在想要什么？ What do you want now?
#  98| 已经 	 +12 	 110 	53.62	 你已经知道了，不是吗？ You knew about this already, didn't you?
# 101| 吧  	 +0 	 101 	33.86	 那不对，对吧？ That isn't true, is it?
# 103| 不是 	 +7 	 110 	53.62	 你已经知道了，不是吗？ You knew about this already, didn't you?
# 107| 走  	 +0 	 107 	58.20	 你什么时候走？ What time are you leaving?
# 109| 呢  	 +0 	 109 	54.67	 还在等什么呢！ What're you waiting for?
# 110| 吗  	 +0 	 110 	57.62	 你知道他们什么时候到吗？ Do you know when they will arrive?
# 113| 问题 	 +0 	 113 	63.00	 有什么问题吗？ Are there any questions?
# 114| 它  	 +0 	 114 	64.20	 它什么时候到？ When does it arrive?
# 115| 如果 	 +0 	 115 	60.00	 如果不是现在，那是什么时候？ If not now, when?
# 117| 啊  	 +0 	 117 	49.20	 那是什么啊？ What is that?
# 118| 工作 	 +0 	 118 	58.20	 你做什么工作？ What is your occupation?
# 119| 才  	 +80 	 199 	53.67	 我才是那个想和你在一起的人！ I'm the one who wants to be with you.
# 123| 问  	 +0 	 123 	57.12	 我可以问你个问题吗？ Can I ask you a question?
# 125| 吃  	 +0 	 125 	80.80	 这个能吃吗？ Is this edible?
# 127| 开始 	 +0 	 127 	55.00	 我可以开始了吗？ Can I begin?
# 133| 事  	 +0 	 133 	61.38	 有什么事我可以做吗？ Is there anything I can do?
# 134| 但是 	 +53 	 187 	62.50	 有什么你想要但是没有的东西吗？ Is there anything you want that you don't have?
# 135| 学生 	 +0 	 135 	57.29	 你也是学生不是吗？ You're a student, too, aren't you?
# 139| 跟  	 +0 	 139 	44.00	 你想跟我说什么？ What do you want to tell me?
# 143| 当  	 +45 	 188 	70.71	 你当你是谁啊？ Who do you think you are?
# 144| 一些 	 +0 	 144 	98.00	 我能问一些问题吗？ May I ask a few questions?
# 147| 还有 	 +0 	 147 	58.14	 这还有什么能做的？ What else can this do?
# 150| 怎么 	 +0 	 150 	76.33	 你知道怎么做吗？ Do you know how to do that?
# 153| 不能 	 +0 	 153 	65.62	 有你不能做的事吗？ Is there anything you can't do?
# 154| 孩子 	 +0 	 154 	39.67	 你的孩子多大了？ How old are your kids?
# 155| 起来 	 +115 	 270 	63.62	 你为什么不和我们一起来？ Why aren't you coming with us?
# 158| 听  	 +0 	 158 	46.57	 你在听我说吗？ Do you hear what I'm saying?
# 159| 一样 	 +0 	 159 	72.14	 他们都像这一样吗？ Are they all like this?
# 160| 叫  	 +0 	 160 	77.25	 这个叫什么？ What do you call this?
# 161| 大家 	 +0 	 161 	78.00	 大家好！ Hi, everybody.
# 163| 可能 	 +0 	 163 	54.00	 这不可能！ It can't be!
# 166| 您  	 +0 	 166 	103.83	 您想听它吗？ Do you want to hear it?
# 170| 高  	 +0 	 170 	52.60	 你有多高？ How tall are you?
# 173| 那么 	 +0 	 173 	73.00	 如果我那么做你会怎么想？ What would you think if I did that?
# 174| 爱  	 +0 	 174 	45.17	 你有多爱我？ How much do you love me?
# 177| 找  	 +0 	 177 	89.50	 您在找什么吗？ Are you looking for something?
# 419| 得到 	 +86 	 505 	161.71	 你从哪得到它的？ Where did you get it?
# 425| 读  	 +0 	 425 	136.88	 为什么你要读这样一本书？ Why do you need to read such a book?
# 427| 文章 	 +0 	 427 	98.33	 你看文章了没？ Did you read the article?
# 429| 些  	 +0 	 429 	96.17	 他们说了些什么？ What did they say?
# 430| 刚  	 +0 	 430 	133.33	 你刚到这里吗？ Did you just get here?
# 437| 少  	 +0 	 437 	129.50	 少了什么？ What is missing?
# 439| 帮  	 +0 	 439 	136.75	 你真的觉得我会帮你吗？ Do you really think I'm going to help you?
# 444| 只要 	 +0 	 444 	272.67	 只要十元！ It only costs $10.00!
# 445| 每天 	 +0 	 445 	160.71	 为什么你每天都学习呢？ Why do you study every day?
# 451| 喝  	 +0 	 451 	156.00	 你们想喝什么？ What would you like to drink?
# 453| 以前 	 +0 	 453 	113.83	 你以前想做什么？ What did you want to do?
# 455| 继续 	 +0 	 455 	170.17	 准备好继续了吗？ Are you ready to proceed?
# 460| 决定 	 +0 	 460 	85.77	 你是决定做这个工作的那个人，对吗？ You're the one who decided to do this job, right?
# 468| 故事 	 +0 	 468 	157.17	 谁写了这个故事？ Who wrote this story?
# 470| 干  	 +0 	 470 	136.25	 干的好！ Good job!
# 471| 越  	 +0 	 471 	126.70	 你知道的越少越好，好吗？ The less you know, the better, OK?
# 481| 专业 	 +0 	 481 	96.50	 你的专业是什么？ What's your major?
# 482| 新闻 	 +149 	 631 	209.17	 你听到新闻了吗？ Did you hear the news?
# 484| 语言 	 +0 	 484 	129.00	 你会几种语言？ How many languages do you know?
# 487| 信  	 +0 	 487 	83.88	 到的有我的信吗？ Have any letters arrived for me?
# 488| 找到 	 +234 	 722 	174.62	 你怎么找到我的房子的？ How did you find my house?
# 494| 儿子 	 +103 	 597 	185.62	 你给你儿子起什么名字？ What did you name your son?
# 496| 一天 	 +405 	 901 	233.00	 美丽的一天，不是吗？ It's a nice day, isn't it?
# 500| 离开 	 +0 	 500 	154.25	 您想知道为什么我要离开吗？ Do you want to know why I quit?
# 503| 啦  	 +0 	 503 	180.60	 想死你啦！ I can't tell you how much we've missed you.
# 505| 哪  	 +0 	 505 	217.00	 我们以后往哪走？ Where will we go afterwards?
# 506| 认识 	 +0 	 506 	207.00	 你们认识吗？ Do you know each other?
# 510| 关于 	 +136 	 646 	208.12	 关于那件事你之前怎么想的？ How did you feel about that?
# 511| 家里 	 +0 	 511 	131.20	 你在家里吗？ Are you at home?
# 513| 不好 	 +0 	 513 	158.75	 那有什么不好？ What's wrong with that?
# 515| 音乐 	 +0 	 515 	166.60	 你喜欢音乐吗？ Do you like music?
# 516| 能力 	 +0 	 516 	107.50	 你有能力去做这个吗？ Were you able to do it?
# 519| 相信 	 +0 	 519 	172.00	 你真的相信那发生了吗？ Do you really believe that's what happened?
# 520| 注意 	 +0 	 520 	131.50	 你没注意到吗？ Didn't you notice?
# 527| 回家 	 +0 	 527 	158.00	 你为什么不回家呢？ Why don't you go home?
# 39710| 爬树 	 +10290 	 50000 	12022.00	 对猴子来说，爬树很容易。 It is easy for a monkey to climb a tree.
# 39755| 错话 	 +10245 	 50000 	7431.00	 要是我说错话被人议论，我是不管的。 I don't mind being criticized when I am wrong.
# 39893| 阵雨 	 +10107 	 50000 	18945.80	 明天天气晴转阵雨。 Tomorrow's weather should be sunny with occasional rain.
# 39934| 电话簿	 +0 	 39934 	10180.00	 电话簿在哪里？ Where's the phone book?
# 39966| 长崎 	 +10034 	 50000 	18001.80	 我去了长崎。 I went to Nagasaki.
# 39969| 毫不费力	 +10031 	 50000 	13330.29	 我们毫不费力地想出了密码。 We easily figured out the password.
# 40058| 白鸽 	 +9942 	 50000 	15832.00	 白鸽是种美丽的鸟类。 White doves are pretty birds.
# 40155| 电炉 	 +9845 	 50000 	19517.20	 这家工厂生产电炉。 This factory manufactures electric stoves.
# 40250| 数以千计	 +9750 	 50000 	12499.40	 数以千计的蜡烛点亮了仪式中的教堂。 Thousands of candles illuminated the church during the ceremony.
# 40437| 耳鸣 	 +0 	 40437 	10144.00	 你耳鸣吗？ Do you have tinnitus?
# 40614| 火柴盒	 +9386 	 50000 	17318.17	 这收音机不比火柴盒大。 This radio is no bigger than a matchbox.
# 40760| 偷工减料	 +9240 	 50000 	10229.11	 他是个绝对不会偷工减料的人。 He is a person who never cuts corners.
# 40876| 禁烟 	 +9124 	 50000 	12306.00	 汤姆讨厌在禁烟区吸烟的人。 Tom doesn't like people who smoke in no smoking areas.
# 40939| 摔断 	 +0 	 40939 	5831.89	 谁告诉你们汤姆把腿摔断的？ Who told you Tom broke his leg?
# 40960| 换工 	 +9040 	 50000 	15540.00	 我得换工服了。 I have to change into my work clothes.
# 41031| 差得远	 +8969 	 50000 	12261.75	 这篇英语作文离完美还差得远。 This English essay is far from perfect.
# 41034| 圆舞曲	 +8966 	 50000 	10250.94	 我觉得李斯特的《被遗忘的圆舞曲第三首》是个被埋没的名曲。 I think that Liszt's "Forgotten Waltz No.3" is a hidden masterpiece.
# 41063| 翻番 	 +8937 	 50000 	18614.80	 今年销售会翻番。 Sales should double this year.
# 41082| 言喻 	 +8918 	 50000 	16032.50	 她的悲伤无法言喻。 No words can express her deep sorrow.
# 41152| 一劳永逸	 +8848 	 50000 	7903.58	 她一劳永逸地告诉我，她不想再见我了。 She told me once and for all that she did not want to see me again.
# 41228| 榔头 	 +8772 	 50000 	7507.82	 对工具箱里只有一把榔头的人来说，所有的问题都像钉子。 To the man who only has a hammer in the toolkit, every problem looks like a nail.
# 41317| 黑海 	 +0 	 41317 	4482.30	 黑海里的水事实上是黑的吗？ Is the water in the Black Sea actually black?
# 41601| 六月份	 +8399 	 50000 	20062.86	 下一场音乐会将在六月份举办。 The next concert will take place in June.
# 41913| 吹灭 	 +8087 	 50000 	12580.33	 汤姆吹灭了蛋糕上的所有蜡烛。 Tom blew out all the candles on the cake.
# 41993| 不劳而获	 +8007 	 50000 	15349.00	 没有什么是不劳而获的。 Nothing is achieved without effort.
# 43773| 装病 	 +6227 	 50000 	18992.88	 玛丽不是真病。她只是装病。 Mary isn't really sick. She's faking it.
# 43778| 共同之处	 +6222 	 50000 	15718.83	 我同他们没有过共同之处。 I had nothing in common with them.
# 43939| 珊瑚礁	 +6061 	 50000 	12377.62	 珊瑚礁是这个地区的主要景点。 The coral reef is the region's prime attraction.
# 44115| 灌肠 	 +0 	 44115 	5917.75	 你见过灌肠的做法吗？ Have you ever seen sausage being made?
# 44217| 打哈欠	 +5783 	 50000 	13782.79	 你咳嗽、打喷嚏或打哈欠的时候要捂住你的嘴。 Cover your mouth when you cough, sneeze, or yawn.
# 44325| 自闭症	 +0 	 44325 	10753.80	 汤姆有自闭症吗？ Is Tom autistic?
# 44336| 一片狼藉	 +5664 	 50000 	19015.40	 他的房间一片狼藉。 His room's a mess.
# 44431| 坚韧不拔	 +5569 	 50000 	14389.12	 学好一门外语需要坚韧不拔的毅力。 Mastering a foreign language involves a lot of patience.
# 44569| 货船 	 +5431 	 50000 	15935.00	 货船早到了四小时。 The cargo ship arrived four hours early.
# 44800| 理所应当	 +5200 	 50000 	13815.71	 他觉得我理所应当知道答案。 He took it for granted that I knew the answer.
# 44818| 茶匙 	 +5182 	 50000 	13089.50	 她用茶匙搅她的咖啡。 She stirred her coffee with a teaspoon.
# 44858| 尿床 	 +5142 	 50000 	13848.71	 别告诉任何人我尿床了。 Don't tell anyone that I wet the bed.
# 44973| 挖土 	 +5027 	 50000 	16031.83	 你可以在地上挖土。 You can dig dirt from the ground.
# 44986| 简而言之	 +5014 	 50000 	16045.83	 简而言之，我不同意。 To put it briefly, I do not agree.
# 45007| 霍乱 	 +4993 	 50000 	14131.29	 去年有两百人因霍乱死亡。 Two hundred people died of cholera last year.
# 45018| 摔成 	 +4982 	 50000 	22254.20	 瓶子摔成了碎片。 The bottle smashed to pieces.
# 45028| 入侵者	 +4972 	 50000 	14885.00	 他们抵御入侵者，保卫了国家。 They defended their country against the invaders.
# 45178| 关窗 	 +4822 	 50000 	11405.82	 你不介意我关窗吧？我有点着凉了。 Would you mind if I shut the window? I have a slight cold.
# 45199| 请帖 	 +4801 	 50000 	16173.00	 我收到了一张请帖。 I received an invitation.
# 45259| 南北战争	 +4741 	 50000 	9656.80	 他写了本关于美国南北战争的书。 He wrote a book about the American Civil War.
# 45390| 混合物	 +4610 	 50000 	18588.17	 空气是气体的混合物。 Air is a mixture of gases.
# 45397| 枪械 	 +0 	 45397 	9030.29	 为什么美国政府让人们持有枪械？ Why does the US government let people have guns?
# 45408| 一月份	 +4592 	 50000 	20353.80	 我一月份要参加考试。 I'm taking an exam in January.
# 45487| 蟾蜍 	 +4513 	 50000 	16034.86	 我无法区分青蛙和蟾蜍。 I can't tell a frog from a toad.
# 45600| 熟稔 	 +4400 	 50000 	16306.22	 我跟那些高個子的女孩很熟稔。 I know those tall girls quite well.
# 45608| 进取心	 +4392 	 50000 	15994.67	 你需要更有进取心。 You need to be aggressive.
# 45761| 三更半夜	 +0 	 45761 	5735.67	 三更半夜不睡觉，你在干嘛呢？ It's the middle of the night. Why aren't you asleep?
# 48291| 漆成 	 +0 	 48291 	9242.62	 为什么你把长凳漆成红色了？ Why did you paint the bench red?
# 48295| 对光 	 +1705 	 50000 	14785.43	 猫的眼睛对光很敏感。 Cats' eyes are very sensitive to light.
# 48324| 浅蓝 	 +1676 	 50000 	20049.60	 天空是浅蓝的。 The sky is light blue.
# 48502| Fi 	 +1498 	 50000 	23453.38	 能不能請你告訴我Wi-Fi的密碼呢? Could you tell me the Wi-Fi password?
# 48521| 电能 	 +1479 	 50000 	10760.80	 澳大利亚在欧洲是最大的电能生产国之一。 Austria is one of the largest producers of electricity in Europe.
# 48567| 印欧语	 +1433 	 50000 	16864.17	 亚美尼亚语是一门印欧语言。 Armenian is an Indo-European language.
# 48634| 平局 	 +1366 	 50000 	20078.60	 比赛以平局结束。 The game ended in a draw.
# 48863| 动怒 	 +1137 	 50000 	18259.17	 汤姆没有动怒的理由。 Tom had no reason to be angry.
# 48893| 牧草 	 +1107 	 50000 	15145.14	 牛在草地上吃牧草。 Cows are eating grass in the meadow.
# 48900| 凄清 	 +1100 	 50000 	17021.17	 我感到凄清与孤独。 I felt sad and lonely.
# 48908| 熨烫 	 +1092 	 50000 	11963.00	 先熨烫领子的里面，然后是外面。 Iron the inside of collars first, and then the outside.
# 49027| 乐观主义	 +973 	 50000 	16556.67	 你是个乐观主义者。 You're an optimist.
# 49042| 暗箱 	 +958 	 50000 	14507.43	 他能为你暗箱操作。 He can pull strings for you.
# 49186| 山地车	 +0 	 49186 	10106.80	 那辆山地车多少钱？ How much is that mountain bike?
# 49367| 认作 	 +633 	 50000 	12616.75	 她把我认作我弟弟了。 She took me for my brother.
# 49517| 停手 	 +0 	 49517 	24770.50	 停手！ Break it up!
# 1765 / 50000 = 3.53 %

# %%
import graphviz

g = graphviz.Digraph("g", strict=True, engine="dot")
#for i in range(20):
#    g.node(word_freq[i]["word"])

ignored = {}
ignored["。"] = True
ignored["！"] = True
ignored["!"] = True
ignored["？"] = True
    
# for i in range(100):
#     for word in sentences[i]["words"]:
#         if not word in ignored:
#             g.edge(sentences[i]["cmn"], word)
#             if len(word) != 1:
#                 for c in word:
#                     if not c in ignored:
#                         g.edge(word, c)

# n = 1000
# for i in range(n):
#     for j in range(n):
#         sim = 0
#         dif = 0
#         dw = " "
#         for word in sentences[i]["words"]:
#             if not word in ignored:
#                 if word in sentences[j]["words"]:
#                     sim += 1
#                 else:
#                     dif += 1
#                     dw = word
#         for word in sentences[j]["words"]:
#             if not word in ignored:
#                 if not word in sentences[i]["words"]:
#                     dif = 100
#                     break
#         if dif == 1:
#             g.edge(sentences[i]["cmn"], sentences[j]["cmn"], label=dw)

n = 20
for i in range(n):
    for j in range(n):
        sim = 0
        dif = 0
        dw = " "
        for word in sentences[i]["words"]:
            if not word in ignored:
                if word in sentences[j]["words"]:
                    sim += 1
                else:
                    dif += 1
                    dw = word
        for word in sentences[j]["words"]:
            if not word in ignored:
                if not word in sentences[i]["words"]:
                    dif = 100
                    break
        if dif == 1:
            g.edge(sentences[i]["cmn"], sentences[j]["cmn"], label=dw)

g
